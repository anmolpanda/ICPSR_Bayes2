# %%
import pandas as pd
import json
import os

# %%
df = pd.read_stata('./kastellac/gay_marriage_megapoll.dta')
df
# Out:
#                poll poll_firm  poll_year     id  statenum      statename  \
# 0     Gall2005Aug22      Gall       2005  80001      21.0       michigan
# 1     Gall2005Aug22      Gall       2005  80002      10.0        georgia
# 2     Gall2005Aug22      Gall       2005  80003      31.0       new york
# 3     Gall2005Aug22      Gall       2005  80004      28.0  new hampshire
# 4     Gall2005Aug22      Gall       2005  80005      42.0          texas
# ...             ...       ...        ...    ...       ...            ...
# 6543  ABC 2004Jan15      ABC        2004  50147      37.0   pennsylvania
# 6544  ABC 2004Jan15      ABC        2004  50149       9.0        florida
# 6545  ABC 2004Jan15      ABC        2004  50151      29.0     new jersey
# 6546  ABC 2004Jan15      ABC        2004  50155       NaN            NaN
# 6547  ABC 2004Jan15      ABC        2004  50159      34.0           ohio
#
#       region_cat  female  race_wbh  edu_cat  ...  black  hispanic  weight  \
# ...

# %%
df.to_excel('./kastellac/gay_marriage_megapoll.xlsx')

# %%
df = pd.read_stata('./kastellac/poststratification 2000.dta')
df
# Out:
#       crace_WBH  cage_cat  cedu_cat  cfemale cstate  _freq  cfreq_state  \
# 0             1         1         1        0     AK    467      21222.0
# 1             1         2         1        0     AK    377      21222.0
# 2             1         3         1        0     AK    419      21222.0
# 3             1         4         1        0     AK    343      21222.0
# 4             1         1         2        0     AK    958      21222.0
# ...         ...       ...       ...      ...    ...    ...          ...
# 4891          3         4         3        1     WY      4      18175.0
# 4892          3         1         4        1     WY      8      18175.0
# 4893          3         2         4        1     WY     16      18175.0
# 4894          3         3         4        1     WY     10      18175.0
# 4895          3         4         4        1     WY      1      18175.0
#
#       cpercent_state cregion
# 0           0.022005    west
# 1           0.017765    west
# ...

# %%
df.to_excel('./kastellac/poststratification 2000.xlsx')

# %%
df = pd.read_stata('./kastellac/state_level_update.dta')
df.to_excel('./kastellac/state_level_update.xlsx')
